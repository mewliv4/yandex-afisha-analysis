# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in d:\anacondanavigator\lib\site-packages (2.0.43)
# Requirement already satisfied: greenlet>=1 in d:\anacondanavigator\lib\site-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in d:\anacondanavigator\lib\site-packages (from sqlalchemy) (4.15.0)

# %%
# !pip install psycopg2
# Out:
# Collecting psycopg2
#   Downloading psycopg2-2.9.12-cp313-cp313-win_amd64.whl.metadata (5.1 kB)
# Downloading psycopg2-2.9.12-cp313-cp313-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.8 MB ? eta -:--:--
#    ---------------------- ----------------- 1.6/2.8 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 5.9 MB/s  0:00:00
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.12

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
db_config = {'user': 'praktikum_student', # имя пользователя
             'pwd': 'Sdf4$2;d-d30pp', # пароль
             'host': 'rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net',
             'port': 6432, # порт подключения
             'db': 'data-analyst-afisha' # название базы данных
             }

# %%
db_url = "postgresql://praktikum_student:Sdf4$2;d-d30pp@rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net:6432/data-analyst-afisha"

# %%
connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
    db_config['user'],
    db_config['pwd'],
    db_config['host'],
    db_config['port'],
    db_config['db'],
)

# %%
engine = create_engine(connection_string)

# %%
query = '''
SELECT *
FROM afisha.purchases
LIMIT 5
'''

# %%
df = pd.read_sql_query(query, con=engine)
